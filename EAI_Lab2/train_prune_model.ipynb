# %% [markdown]
# ## 掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 更改檔案所在路徑

# %%
# # Change to your own folder !!!
# %cd /content/drive/MyDrive/your own folder/

# %% [markdown]
# ## Import library

# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from models.resnet import ResNet50

# %% [markdown]
# ## 設定超參數

# %%
SEED = 1
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 20
LEARNING_RATE = 1e-3
LOG_INTERVAL = 100
CUDA = True

RESUME = True
START_EPOCH = 0

PRUNE_PATH = 'bestmodel/model_prune09.pth' # Change to your own folder !!!
PRUNE_FINETUNE_PATH = 'bestmodel/model_prune_finetune09.pth' # Change to your own folder !!!

# %% [markdown]
# #### 檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  cfg = checkpoint['cfg']
  model = ResNet50(num_classes=10,cfg=cfg)
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ## 設定 Optimizer & CrossEntropy Loss

# %%
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!
train_acc = []
test_acc = []
def train(epoch):
    model.train()
    accuracy_per_batch = []
    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        pred = output.data.max(1, keepdim=True)[1]

        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

        correct = pred.eq(target.data.view_as(pred)).cpu().sum()
        accuracy = correct / float(len(data))
        accuracy_per_batch.append(accuracy)
    train_acc.append(sum(accuracy_per_batch)/len(accuracy_per_batch))
#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)

          output = model(data)
          loss = criterion(output, target)
          test_loss += loss.item() * data.size(0)

          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)

      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
    test_acc.append(correct/float(len(test_loader.dataset)))
    return correct / float(len(test_loader.dataset))


best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重
    if(prec1 > best_prec1):
        best_prec1 = prec1
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
            'cfg': cfg
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.816711
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 0.240617
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 0.419460
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 0.448892
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 0.376977
#
# Test set: Average loss: 0.4652, Accuracy: 8484/10000 (84.8%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.399656
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 0.452763
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 0.351677
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 0.358721
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 0.518084
#
# Test set: Average loss: 0.4573, Accuracy: 8527/10000 (85.3%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.490596
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 0.348431
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 0.291154
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 0.258823
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.158651
#
# Test set: Average loss: 0.4468, Accuracy: 8559/10000 (85.6%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.225665
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.364454
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.409425
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.162826
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.381778
#
# Test set: Average loss: 0.4231, Accuracy: 8622/10000 (86.2%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.267432
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.261883
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.168738
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.180805
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.330835
#
# Test set: Average loss: 0.4415, Accuracy: 8606/10000 (86.1%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.320395
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.280725
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.358292
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.530485
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.280267
#
# Test set: Average loss: 0.4193, Accuracy: 8692/10000 (86.9%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.213495
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.411160
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.394436
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.327918
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.360965
#
# Test set: Average loss: 0.4422, Accuracy: 8597/10000 (86.0%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.227995
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.442669
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.285748
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.318596
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.240990
#
# Test set: Average loss: 0.4191, Accuracy: 8741/10000 (87.4%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.386431
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.472024
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.207912
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.395306
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.316575
#
# Test set: Average loss: 0.3951, Accuracy: 8779/10000 (87.8%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.174537
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.232149
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.134352
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.225555
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.369793
#
# Test set: Average loss: 0.4061, Accuracy: 8726/10000 (87.3%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.276492
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.201244
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.136325
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.156710
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.110260
#
# Test set: Average loss: 0.3357, Accuracy: 8993/10000 (89.9%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.114134
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.120226
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.083470
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.106315
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.124407
#
# Test set: Average loss: 0.3376, Accuracy: 9011/10000 (90.1%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.136481
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.128571
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.170981
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.100654
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.183972
#
# Test set: Average loss: 0.3366, Accuracy: 9029/10000 (90.3%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.118223
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.164400
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.169115
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.111889
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.200688
#
# Test set: Average loss: 0.3395, Accuracy: 9043/10000 (90.4%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.089931
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.121153
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.098029
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.058597
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.185501
#
# Test set: Average loss: 0.3523, Accuracy: 9013/10000 (90.1%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.154067
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.225183
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.122871
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.124110
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.123253
#
# Test set: Average loss: 0.3423, Accuracy: 9064/10000 (90.6%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.103607
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.050757
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.148406
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.165970
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.107831
#
# Test set: Average loss: 0.3412, Accuracy: 9058/10000 (90.6%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.070953
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.125639
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.074384
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.065122
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.047354
#
# Test set: Average loss: 0.3423, Accuracy: 9054/10000 (90.5%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.075181
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.244561
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.125507
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.106450
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.089551
#
# Test set: Average loss: 0.3401, Accuracy: 9064/10000 (90.6%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.215803
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.232060
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.109583
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.157822
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.134201
#
# Test set: Average loss: 0.3388, Accuracy: 9072/10000 (90.7%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))

epochs = np.arange(1, EPOCHS + 1)

plt.plot(epochs, train_acc, marker='o', label='Train')
plt.plot(epochs, test_acc, marker='s', label='Test')

for x, y in zip(epochs, train_acc):
    plt.text(x, y, f'{y:.3f}', ha='center', va='bottom', fontsize=9, color='blue')
for x, y in zip(epochs, test_acc):
    plt.text(x, y, f'{y:.3f}', ha='center', va='bottom', fontsize=9, color='orange')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Fine-tune Accuracy')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

plt.savefig('result/train_accuracy_pruned_model.png')
plt.show()

# %% [markdown]
# ## FLOPs & Parameters

# %%
# !pip install thop
# !pip install torchsummary

# %%
from thop import profile
from torchsummary import summary

##### 使用 thop 計算 FLOPs 和參數數量 #####
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

dummy_input = torch.randn(1, 3, 32, 32).to(device)
flops, params = profile(model, inputs=(dummy_input, ))

print(f"FLOPs: {flops}")
print(f"Params: {params}")
summary(model, input_size=(3, 32, 32))
# Out:
# Device: cuda
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs: 131086024.0
# Params: 3729889.0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-12          [-1, 256, 16, 16]             512
#            Conv2d-13          [-1, 256, 16, 16]          16,384
#              ReLU-14          [-1, 256, 16, 16]               0
#        Bottleneck-15          [-1, 256, 16, 16]               0
#            Conv2d-16           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-17           [-1, 64, 16, 16]             128
#              ReLU-18           [-1, 64, 16, 16]               0
#            Conv2d-19           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#            Conv2d-22          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-23          [-1, 256, 16, 16]             512
#              ReLU-24          [-1, 256, 16, 16]               0
#        Bottleneck-25          [-1, 256, 16, 16]               0
#            Conv2d-26           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-27           [-1, 64, 16, 16]             128
#              ReLU-28           [-1, 64, 16, 16]               0
#            Conv2d-29           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-30           [-1, 64, 16, 16]             128
#              ReLU-31           [-1, 64, 16, 16]               0
#            Conv2d-32          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-33          [-1, 256, 16, 16]             512
#              ReLU-34          [-1, 256, 16, 16]               0
#        Bottleneck-35          [-1, 256, 16, 16]               0
#            Conv2d-36          [-1, 119, 16, 16]          30,464
#       BatchNorm2d-37          [-1, 119, 16, 16]             238
#              ReLU-38          [-1, 119, 16, 16]               0
#            Conv2d-39            [-1, 124, 8, 8]         132,804
#       BatchNorm2d-40            [-1, 124, 8, 8]             248
#              ReLU-41            [-1, 124, 8, 8]               0
#            Conv2d-42            [-1, 512, 8, 8]          63,488
#       BatchNorm2d-43            [-1, 512, 8, 8]           1,024
#            Conv2d-44            [-1, 512, 8, 8]         131,072
#              ReLU-45            [-1, 512, 8, 8]               0
#        Bottleneck-46            [-1, 512, 8, 8]               0
#            Conv2d-47            [-1, 107, 8, 8]          54,784
#       BatchNorm2d-48            [-1, 107, 8, 8]             214
#              ReLU-49            [-1, 107, 8, 8]               0
#            Conv2d-50            [-1, 122, 8, 8]         117,486
#       BatchNorm2d-51            [-1, 122, 8, 8]             244
#              ReLU-52            [-1, 122, 8, 8]               0
#            Conv2d-53            [-1, 512, 8, 8]          62,464
#       BatchNorm2d-54            [-1, 512, 8, 8]           1,024
#              ReLU-55            [-1, 512, 8, 8]               0
#        Bottleneck-56            [-1, 512, 8, 8]               0
#            Conv2d-57             [-1, 78, 8, 8]          39,936
#       BatchNorm2d-58             [-1, 78, 8, 8]             156
#              ReLU-59             [-1, 78, 8, 8]               0
#            Conv2d-60             [-1, 77, 8, 8]          54,054
#       BatchNorm2d-61             [-1, 77, 8, 8]             154
#              ReLU-62             [-1, 77, 8, 8]               0
#            Conv2d-63            [-1, 512, 8, 8]          39,424
#       BatchNorm2d-64            [-1, 512, 8, 8]           1,024
#              ReLU-65            [-1, 512, 8, 8]               0
#        Bottleneck-66            [-1, 512, 8, 8]               0
#            Conv2d-67             [-1, 21, 8, 8]          10,752
#       BatchNorm2d-68             [-1, 21, 8, 8]              42
#              ReLU-69             [-1, 21, 8, 8]               0
#            Conv2d-70             [-1, 20, 8, 8]           3,780
#       BatchNorm2d-71             [-1, 20, 8, 8]              40
#              ReLU-72             [-1, 20, 8, 8]               0
#            Conv2d-73            [-1, 512, 8, 8]          10,240
#       BatchNorm2d-74            [-1, 512, 8, 8]           1,024
#              ReLU-75            [-1, 512, 8, 8]               0
#        Bottleneck-76            [-1, 512, 8, 8]               0
#            Conv2d-77             [-1, 15, 8, 8]           7,680
#       BatchNorm2d-78             [-1, 15, 8, 8]              30
#              ReLU-79             [-1, 15, 8, 8]               0
#            Conv2d-80              [-1, 3, 4, 4]             405
#       BatchNorm2d-81              [-1, 3, 4, 4]               6
#              ReLU-82              [-1, 3, 4, 4]               0
#            Conv2d-83           [-1, 1024, 4, 4]           3,072
#       BatchNorm2d-84           [-1, 1024, 4, 4]           2,048
#            Conv2d-85           [-1, 1024, 4, 4]         524,288
#              ReLU-86           [-1, 1024, 4, 4]               0
#        Bottleneck-87           [-1, 1024, 4, 4]               0
#            Conv2d-88              [-1, 3, 4, 4]           3,072
#       BatchNorm2d-89              [-1, 3, 4, 4]               6
#              ReLU-90              [-1, 3, 4, 4]               0
#            Conv2d-91              [-1, 4, 4, 4]             108
#       BatchNorm2d-92              [-1, 4, 4, 4]               8
#              ReLU-93              [-1, 4, 4, 4]               0
#            Conv2d-94           [-1, 1024, 4, 4]           4,096
#       BatchNorm2d-95           [-1, 1024, 4, 4]           2,048
#              ReLU-96           [-1, 1024, 4, 4]               0
#        Bottleneck-97           [-1, 1024, 4, 4]               0
#            Conv2d-98              [-1, 3, 4, 4]           3,072
#       BatchNorm2d-99              [-1, 3, 4, 4]               6
#             ReLU-100              [-1, 3, 4, 4]               0
#           Conv2d-101              [-1, 3, 4, 4]              81
#      BatchNorm2d-102              [-1, 3, 4, 4]               6
#             ReLU-103              [-1, 3, 4, 4]               0
#           Conv2d-104           [-1, 1024, 4, 4]           3,072
#      BatchNorm2d-105           [-1, 1024, 4, 4]           2,048
#             ReLU-106           [-1, 1024, 4, 4]               0
#       Bottleneck-107           [-1, 1024, 4, 4]               0
#           Conv2d-108              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-109              [-1, 3, 4, 4]               6
#             ReLU-110              [-1, 3, 4, 4]               0
#           Conv2d-111              [-1, 3, 4, 4]              81
#      BatchNorm2d-112              [-1, 3, 4, 4]               6
#             ReLU-113              [-1, 3, 4, 4]               0
#           Conv2d-114           [-1, 1024, 4, 4]           3,072
#      BatchNorm2d-115           [-1, 1024, 4, 4]           2,048
#             ReLU-116           [-1, 1024, 4, 4]               0
#       Bottleneck-117           [-1, 1024, 4, 4]               0
#           Conv2d-118              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-119              [-1, 3, 4, 4]               6
#             ReLU-120              [-1, 3, 4, 4]               0
#           Conv2d-121              [-1, 3, 4, 4]              81
#      BatchNorm2d-122              [-1, 3, 4, 4]               6
#             ReLU-123              [-1, 3, 4, 4]               0
#           Conv2d-124           [-1, 1024, 4, 4]           3,072
#      BatchNorm2d-125           [-1, 1024, 4, 4]           2,048
#             ReLU-126           [-1, 1024, 4, 4]               0
#       Bottleneck-127           [-1, 1024, 4, 4]               0
#           Conv2d-128              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-129              [-1, 3, 4, 4]               6
#             ReLU-130              [-1, 3, 4, 4]               0
#           Conv2d-131              [-1, 3, 4, 4]              81
#      BatchNorm2d-132              [-1, 3, 4, 4]               6
#             ReLU-133              [-1, 3, 4, 4]               0
#           Conv2d-134           [-1, 1024, 4, 4]           3,072
#      BatchNorm2d-135           [-1, 1024, 4, 4]           2,048
#             ReLU-136           [-1, 1024, 4, 4]               0
#       Bottleneck-137           [-1, 1024, 4, 4]               0
#           Conv2d-138              [-1, 9, 4, 4]           9,216
#      BatchNorm2d-139              [-1, 9, 4, 4]              18
#             ReLU-140              [-1, 9, 4, 4]               0
#           Conv2d-141              [-1, 3, 2, 2]             243
#      BatchNorm2d-142              [-1, 3, 2, 2]               6
#             ReLU-143              [-1, 3, 2, 2]               0
#           Conv2d-144           [-1, 2048, 2, 2]           6,144
#      BatchNorm2d-145           [-1, 2048, 2, 2]           4,096
#           Conv2d-146           [-1, 2048, 2, 2]       2,097,152
#             ReLU-147           [-1, 2048, 2, 2]               0
#       Bottleneck-148           [-1, 2048, 2, 2]               0
#           Conv2d-149              [-1, 3, 2, 2]           6,144
#      BatchNorm2d-150              [-1, 3, 2, 2]               6
#             ReLU-151              [-1, 3, 2, 2]               0
#           Conv2d-152              [-1, 6, 2, 2]             162
#      BatchNorm2d-153              [-1, 6, 2, 2]              12
#             ReLU-154              [-1, 6, 2, 2]               0
#           Conv2d-155           [-1, 2048, 2, 2]          12,288
#      BatchNorm2d-156           [-1, 2048, 2, 2]           4,096
#             ReLU-157           [-1, 2048, 2, 2]               0
#       Bottleneck-158           [-1, 2048, 2, 2]               0
#           Conv2d-159              [-1, 3, 2, 2]           6,144
#      BatchNorm2d-160              [-1, 3, 2, 2]               6
#             ReLU-161              [-1, 3, 2, 2]               0
#           Conv2d-162              [-1, 3, 2, 2]              81
#      BatchNorm2d-163              [-1, 3, 2, 2]               6
#             ReLU-164              [-1, 3, 2, 2]               0
#           Conv2d-165           [-1, 2048, 2, 2]           6,144
#      BatchNorm2d-166           [-1, 2048, 2, 2]           4,096
#             ReLU-167           [-1, 2048, 2, 2]               0
#       Bottleneck-168           [-1, 2048, 2, 2]               0
# AdaptiveAvgPool2d-169           [-1, 2048, 1, 1]               0
#           Linear-170                   [-1, 10]          20,490
# ================================================================
# Total params: 3,729,889
# Trainable params: 3,729,889
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 20.12
# Params size (MB): 14.23
# Estimated Total Size (MB): 34.36
# ----------------------------------------------------------------
